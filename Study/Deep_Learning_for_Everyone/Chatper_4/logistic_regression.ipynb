# %% [markdown]
# <a href="https://colab.research.google.com/github/godpeny/laboratory/blob/master/Study/Deep_Learning_for_Everyone/Chatper_4/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install
# %pip install tensorflow
# %pip install numpy
# %pip install matplotlib

# %%
# import
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
x = np.array([2,4,6,8,10,12])
y = np.array([0,0,0,1,1,1,])

model = Sequential()

model.add(Dense(1, input_dim=1, activation='sigmoid'))
model.compile(optimizer='sgd', loss='binary_crossentropy')
model.fit(x,y,epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 584ms/step - loss: 0.7270
# Epoch 2/2000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7116
# Epoch 3/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6976
# Epoch 4/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6850
# Epoch 5/2000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6737
# Epoch 6/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6637
# Epoch 7/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6550
# Epoch 8/2000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6473
# Epoch 9/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6407
# Epoch 10/2000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6350
# Epoch 11/2000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6302
# Epoch 12/2000
# ...

# %%
pred = model.predict([7])
print(pred)
# Out:
# 1/1 [==============================] - 0s 42ms/step
# [[0.6163079]]

# %%
plt.scatter(x,y)
plt.plot(x, model.predict(x), 'b')
plt.show()
# Out:
# 1/1 [==============================] - 0s 109ms/step
