# %%
# import
from tensorflow.keras.layers import Dense, Input, concatenate, LSTM
from tensorflow.keras.models import Model
from tensorflow.keras import optimizers

# %% [markdown]
# # Basic

# %%
input = Input(shape=(10,))
hidden1 = Dense(64,activation='relu')(input)
hidden2 = Dense(64,activation='relu')(hidden1)
output = Dense(1,activation='sigmoid')(hidden2)

model = Model(inputs=input, outputs=output)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Linear Regression

# %%
x = [1, 2, 3, 4, 5, 6, 7, 8, 9] 
y = [11, 22, 33, 44, 53, 66, 77, 87, 95] 

input = Input(shape=(1,))
output = Dense(1, activation='linear')(input)

model = Model(inputs=input, outputs=output)
model.compile(optimizer='adam', loss='mse', metrics=['mse'])

model.fit(x, y, epochs=300, verbose=1)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 0s 147ms/step - loss: 4674.0801 - mse: 4674.0801
# Epoch 2/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4673.1895 - mse: 4673.1895
# Epoch 3/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4672.2983 - mse: 4672.2983
# Epoch 4/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4671.4067 - mse: 4671.4067
# Epoch 5/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4670.5161 - mse: 4670.5161
# Epoch 6/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4669.6250 - mse: 4669.6250
# Epoch 7/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4668.7349 - mse: 4668.7349
# Epoch 8/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4667.8442 - mse: 4667.8442
# Epoch 9/300
# 1/1 [==============================] - 0s 3ms/step - loss: 4666.9536 - mse: 4666.9536
# Epoch 10/300
# ...

# %% [markdown]
# # Logistic Regression

# %%
inputs = Input(shape=(3,))
output = Dense(1, activation='sigmoid')(inputs)
logistic_model = Model(inputs, output)

# %% [markdown]
# # Multiple Inputs

# %%
inputA = Input(shape=(64,))
inputB = Input(shape=(128,))

x_input_layer = Dense(16, activation='relu')(inputA)
x_output_layer = Dense(8, activation='relu')(x_input_layer)

y_input_layer = Dense(64, activation='relu')(inputB)
y_hidden_layer_1 = Dense(32, activation='relu')(y_input_layer)
y_output_layer = Dense(8, activation='relu')(y_hidden_layer_1)

model_x = Model(inputs=inputA, outputs=x_output_layer)
model_y = Model(inputs=inputB, outputs=y_output_layer)

combined = concatenate([model_x.output, model_y.output])

z_input = Dense(2, activation='relu')(combined)
z_output = Dense(1, activation='linear')(z_input)

model_z = Model(inputs=[model_x.input, model_y.input], outputs=z_output)
model_z.summary()
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_11 (InputLayer)       [(None, 128)]                0         []
#
#  input_10 (InputLayer)       [(None, 64)]                 0         []
#
#  dense_22 (Dense)            (None, 64)                   8256      ['input_11[0][0]']
#
#  dense_20 (Dense)            (None, 16)                   1040      ['input_10[0][0]']
#
#  dense_23 (Dense)            (None, 32)                   2080      ['dense_22[0][0]']
#
#  dense_21 (Dense)            (None, 8)                    136       ['dense_20[0][0]']
#
#  dense_24 (Dense)            (None, 8)                    264       ['dense_23[0][0]']
#
#  concatenate_2 (Concatenate  (None, 16)                   0         ['dense_21[0][0]',
#  )                                                                   'dense_24[0][0]']
#
# ...

# %% [markdown]
# # RNN

# %%
input_layer = Input(shape=(50, 1))
lstm_layer = LSTM(10)(input_layer)
hidden_layer = Dense(10, activation='relu')(lstm_layer)
output = Dense(1, activation='sigmoid')(hidden_layer)

model_rnn = Model(inputs=input_layer, outputs=output)
model_rnn.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_14 (InputLayer)       [(None, 50, 1)]           0
#
#  lstm_2 (LSTM)               (None, 10)                480
#
#  dense_29 (Dense)            (None, 10)                110
#
#  dense_30 (Dense)            (None, 1)                 11
#
# ...
# Total params: 601 (2.35 KB)
# Trainable params: 601 (2.35 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
